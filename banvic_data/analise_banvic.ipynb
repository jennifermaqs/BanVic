# %% [markdown]
# INICIO DE ANÁLISE BANVIC - DESAFIO INDICIUM

# %% [markdown]
# Estudo de arquivos

# %%
import pandas as pd

# %%
df_agencias = pd.read_csv('agencias.csv')
df_clientes = pd.read_csv('clientes.csv')
df_colaborador_agencia = pd.read_csv('colaborador_agencia.csv')
df_colaboradores = pd.read_csv('colaboradores.csv')
df_contas = pd.read_csv('contas.csv')
df_credito = pd.read_csv('propostas_credito.csv')
df_transacoes = pd.read_csv('transacoes.csv')

# %%
df_agencias.head()
# Out:
#    cod_agencia              nome  \
# 0            7   Agência Digital
# 1            1    Agência Matriz
# 2            2   Agência Tatuapé
# 3            3  Agência Campinas
# 4            4    Agência Osasco
#
#                                             endereco     cidade  uf  \
# 0  Av. Paulista, 1436 - Cerqueira César, São Paul...  São Paulo  SP
# 1  Av. Paulista, 1436 - Cerqueira César, São Paul...  São Paulo  SP
# 2  Praça Sílvio Romero, 158 - Tatuapé, São Paulo ...  São Paulo  SP
# 3  Av. Francisco Glicério, 895 - Vila Lidia, Camp...   Campinas  SP
# 4  Av. Antônio Carlos Costa, 1000 - Bela Vista, O...     Osasco  SP
#
#   data_abertura tipo_agencia
# 0    2015-08-01      Digital
# 1    2010-01-01       Física
# 2    2010-06-14       Física
# 3    2012-03-04       Física
# 4    2013-11-06       Física

# %%
df_agencias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cod_agencia    10 non-null     int64
#  1   nome           10 non-null     object
#  2   endereco       10 non-null     object
#  3   cidade         10 non-null     object
#  4   uf             10 non-null     object
#  5   data_abertura  10 non-null     object
#  6   tipo_agencia   10 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 692.0+ bytes

# %%
df_clientes.head()
# Out:
#    cod_cliente primeiro_nome ultimo_nome                         email  \
# 0           28       Sabrina        Dias  moreiraemanuelly@example.org
# 1          674   Luiz Felipe        Dias     pedroferreira@example.org
# 2          693         Renan        Dias            ogomes@example.net
# 3          743         Clara        Dias     rafaelcorreia@example.org
# 4          769         André        Dias          danilo33@example.org
#
#   tipo_cliente            data_inclusao         cpfcnpj data_nascimento  \
# 0           PF  2017-04-03 16:11:00 UTC  357.081.496-39      2006-08-11
# 1           PF  2021-02-10 13:27:00 UTC  085.196.374-93      1995-10-11
# 2           PF  2020-01-21 13:12:00 UTC  783.416.059-10      1948-11-19
# 3           PF  2019-05-06 11:39:00 UTC  589.237.610-95      1978-01-27
# 4           PF  2017-01-07 14:53:00 UTC  459.608.721-02      1990-08-25
#
#                                             endereco        cep
# ...

# %%
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cod_cliente      998 non-null    int64
#  1   primeiro_nome    998 non-null    object
#  2   ultimo_nome      998 non-null    object
#  3   email            998 non-null    object
#  4   tipo_cliente     998 non-null    object
#  5   data_inclusao    998 non-null    object
#  6   cpfcnpj          998 non-null    object
#  7   data_nascimento  998 non-null    object
#  8   endereco         998 non-null    object
#  9   cep              998 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 78.1+ KB

# %%
df_colaborador_agencia.head()
# Out:
#    cod_colaborador  cod_agencia
# 0                7            1
# 1               13            1
# 2               14            1
# 3               23            1
# 4               24            1

# %%
df_colaborador_agencia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cod_colaborador  100 non-null    int64
#  1   cod_agencia      100 non-null    int64
# dtypes: int64(2)
# memory usage: 1.7 KB

# %%
df_colaboradores.head()
# Out:
#    cod_colaborador  primeiro_nome ultimo_nome                           email  \
# 0               14          Paulo        Dias        melissalopes@example.net
# 1               19  Luiz Fernando        Dias              pcunha@example.net
# 2               32     Vitor Hugo        Dias       aragaonicolas@example.net
# 3               88   João Gabriel        Lima  luiz-otaviorezende@example.org
# 4               39  Maria Eduarda        Melo        joao-pedro72@example.com
#
#               cpf data_nascimento  \
# 0  847.210.695-02      1974-04-24
# 1  820.415.963-33      1994-07-10
# 2  936.172.548-37      1986-12-18
# 3  967.082.451-67      1994-10-19
# 4  857.496.210-49      1996-03-01
#
#                                             endereco        cep
# 0  Lagoa de Rodrigues, 62 Zilah Sposito 37328-273...   27275674
# 1  Ladeira de Moreira, 82 Jardim Atlântico 27617-...   50013962
# 2  Área Sophie Moreira Maria Virgínia 71941-111 S...  08955-215
# ...

# %%
df_colaboradores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cod_colaborador  100 non-null    int64
#  1   primeiro_nome    100 non-null    object
#  2   ultimo_nome      100 non-null    object
#  3   email            100 non-null    object
#  4   cpf              100 non-null    object
#  5   data_nascimento  100 non-null    object
#  6   endereco         100 non-null    object
#  7   cep              100 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 6.4+ KB

# %%
df_contas.head()
# Out:
#    num_conta  cod_cliente  cod_agencia  cod_colaborador tipo_conta  \
# 0         53           53            1                7         PF
# 1        190          190            1                7         PF
# 2        191          191            1                7         PF
# 3        203          203            1                7         PF
# 4        254          254            1                7         PF
#
#              data_abertura  saldo_total  saldo_disponivel  \
# 0  2011-05-24 15:30:00 UTC    2984.7615           2814.67
# 1  2014-10-17 14:48:00 UTC    4262.4322           4191.86
# 2  2013-03-23 14:14:00 UTC    3266.5680           3080.71
# 3  2016-08-03 16:13:00 UTC   21241.5424          19461.56
# 4  2012-10-24 13:48:00 UTC   13335.6966          13197.54
#
#     data_ultimo_lancamento
# 0  2019-07-02 11:03:46 UTC
# 1  2021-03-25 12:00:15 UTC
# 2  2016-09-09 23:34:15 UTC
# 3  2022-12-28 07:58:24 UTC
# 4  2013-12-20 22:20:00 UTC

# %%
df_contas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   num_conta               999 non-null    int64
#  1   cod_cliente             999 non-null    int64
#  2   cod_agencia             999 non-null    int64
#  3   cod_colaborador         999 non-null    int64
#  4   tipo_conta              999 non-null    object
#  5   data_abertura           999 non-null    object
#  6   saldo_total             999 non-null    float64
#  7   saldo_disponivel        999 non-null    float64
#  8   data_ultimo_lancamento  999 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 70.4+ KB

# %%
df_credito.head()
# Out:
#    cod_proposta  cod_cliente  cod_colaborador    data_entrada_proposta  \
# 0           116          338                1  2014-05-30 18:43:12 UTC
# 1           715           45                1  2021-06-17 13:09:32 UTC
# 2           755          494                1  2021-08-10 04:24:02 UTC
# 3           953          381                1  2011-02-23 07:57:58 UTC
# 4          1046          176                1  2010-11-15 16:03:28 UTC
#
#    taxa_juros_mensal  valor_proposta  valor_financiamento  valor_entrada  \
# 0             0.0194    36199.950355             50032.03   13832.079645
# 1             0.0131    12897.538285             19848.55    6951.011715
# 2             0.0203   122236.312551            187154.36   64918.047449
# 3             0.0167    47784.649757             59530.61   11745.960243
# 4             0.0211   178393.038243            214294.19   35901.151757
#
#    valor_prestacao  quantidade_parcelas  carencia status_proposta
# ...

# %%
df_credito.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cod_proposta           2000 non-null   int64
#  1   cod_cliente            2000 non-null   int64
#  2   cod_colaborador        2000 non-null   int64
#  3   data_entrada_proposta  2000 non-null   object
#  4   taxa_juros_mensal      2000 non-null   float64
#  5   valor_proposta         2000 non-null   float64
#  6   valor_financiamento    2000 non-null   float64
#  7   valor_entrada          2000 non-null   float64
#  8   valor_prestacao        2000 non-null   float64
#  9   quantidade_parcelas    2000 non-null   int64
#  10  carencia               2000 non-null   int64
#  11  status_proposta        2000 non-null   object
# dtypes: float64(5), int64(5), object(2)
# memory usage: 187.6+ KB

# %%
df_transacoes.head()
# Out:
#    cod_transacao  num_conta           data_transacao nome_transacao  \
# 0           3100        256  2020-05-22 03:15:21 UTC          Saque
# 1          28405        256  2021-06-29 11:52:38 UTC          Saque
# 2           1776        512  2020-05-17 13:04:50 UTC          Saque
# 3          14311        512  2020-09-06 02:55:34 UTC          Saque
# 4          25012        512  2020-10-16 09:26:52 UTC          Saque
#
#    valor_transacao
# 0           -130.0
# 1           -255.0
# 2           -250.0
# 3            -80.0
# 4           -475.0

# %%
df_transacoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71999 entries, 0 to 71998
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cod_transacao    71999 non-null  int64
#  1   num_conta        71999 non-null  int64
#  2   data_transacao   71999 non-null  object
#  3   nome_transacao   71999 non-null  object
#  4   valor_transacao  71999 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.7+ MB

# %%
df_agencias.describe()
# Out:
#        cod_agencia
# count     10.00000
# mean       5.50000
# std        3.02765
# min        1.00000
# 25%        3.25000
# 50%        5.50000
# 75%        7.75000
# max       10.00000

# %%
df_clientes.describe()
# Out:
#        cod_cliente
# count   998.000000
# mean    499.971944
# std     288.674061
# min       1.000000
# 25%     250.250000
# 50%     499.500000
# 75%     749.750000
# max     999.000000

# %%
df_colaborador_agencia.describe()
# Out:
#        cod_colaborador  cod_agencia
# count       100.000000   100.000000
# mean         50.500000     4.990000
# std          29.011492     3.016771
# min           1.000000     1.000000
# 25%          25.750000     2.000000
# 50%          50.500000     5.000000
# 75%          75.250000     7.250000
# max         100.000000    10.000000

# %%
df_colaboradores.describe()
# Out:
#        cod_colaborador
# count       100.000000
# mean         50.500000
# std          29.011492
# min           1.000000
# 25%          25.750000
# 50%          50.500000
# 75%          75.250000
# max         100.000000

# %%
df_contas.describe()
# Out:
#         num_conta  cod_cliente  cod_agencia  cod_colaborador    saldo_total  \
# count  999.000000   999.000000   999.000000       999.000000     999.000000
# mean   500.000000   500.000000     5.211211        52.997998   26543.407216
# std    288.530761   288.530761     2.432338        27.558209   41872.096136
# min      1.000000     1.000000     1.000000         1.000000       1.221000
# 25%    250.500000   250.500000     3.000000        26.000000     938.142000
# 50%    500.000000   500.000000     7.000000        54.000000   11668.146700
# 75%    749.500000   749.500000     7.000000        83.500000   35410.108600
# max    999.000000   999.000000    10.000000       100.000000  419923.177800
#
#        saldo_disponivel
# count        999.000000
# mean       25731.185586
# std        40288.019468
# min            0.600000
# 25%          918.485000
# 50%        11325.960000
# 75%        33926.210000
# max       411617.060000

# %%
df_credito.describe()
# Out:
#        cod_proposta  cod_cliente  cod_colaborador  taxa_juros_mensal  \
# count   2000.000000  2000.000000      2000.000000        2000.000000
# mean    1000.500000   505.638000        51.588000           0.016682
# std      577.494589   287.751477        28.600162           0.004933
# min        1.000000     2.000000         1.000000           0.008000
# 25%      500.750000   252.000000        27.000000           0.012400
# 50%     1000.500000   508.000000        52.000000           0.016800
# 75%     1500.250000   756.000000        76.000000           0.021000
# max     2000.000000   999.000000       100.000000           0.025000
#
#        valor_proposta  valor_financiamento  valor_entrada  valor_prestacao  \
# count     2000.000000          2000.000000    2000.000000      2000.000000
# mean     83890.490070        124758.355855   40867.865785      4881.837965
# std      51178.425752         72738.017686   28030.837804     12884.892419
# ...

# %%
df_transacoes.describe()
# Out:
#        cod_transacao     num_conta  valor_transacao
# count   71999.000000  71999.000000     71999.000000
# mean    36000.000000    499.486632       357.025159
# std     20784.465353    288.907850      6550.523464
# min         1.000000      1.000000   -132100.000000
# 25%     18000.500000    249.000000      -121.870000
# 50%     36000.000000    499.000000       -39.810000
# 75%     53999.500000    749.000000       -12.860000
# max     71999.000000    999.000000    480270.000000

# %%
df_agencias['data_abertura'] = pd.to_datetime(df_agencias['data_abertura']) 
df_clientes['data_inclusao'] = pd.to_datetime(df_clientes['data_inclusao']) 
df_clientes['data_nascimento'] = pd.to_datetime(df_clientes['data_nascimento']) 
df_colaboradores['data_nascimento'] = pd.to_datetime(df_colaboradores['data_nascimento']) 
df_contas['data_abertura'] = pd.to_datetime(df_contas['data_abertura'], format='mixed') 
df_contas['data_ultimo_lancamento'] = pd.to_datetime(df_contas['data_ultimo_lancamento'], format='mixed')
df_credito['data_entrada_proposta'] = pd.to_datetime(df_credito['data_entrada_proposta'], format='mixed') 
df_transacoes['data_transacao'] = pd.to_datetime(df_transacoes['data_transacao'], format='mixed')

# %%
#verificacao depois da limpeza
df_agencias.info()
print("\n")
df_clientes.info()
print("\n")
df_colaborador_agencia.info()
print("\n")
df_colaboradores.info()
print("\n")
df_contas.info()
print("\n")
df_credito.info()
print("\n")
df_transacoes.info()
print("\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cod_agencia    10 non-null     int64
#  1   nome           10 non-null     object
#  2   endereco       10 non-null     object
#  3   cidade         10 non-null     object
#  4   uf             10 non-null     object
#  5   data_abertura  10 non-null     datetime64[ns]
#  6   tipo_agencia   10 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 692.0+ bytes
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cod_cliente      998 non-null    int64
#  1   primeiro_nome    998 non-null    object
#  2   ultimo_nome      998 non-null    object
#  3   email            998 non-null    object
# ...

# %%
#conexao de tabelas

df_clientes_contas = pd.merge(df_contas, df_clientes, on='cod_cliente', how='left')
df_clientes_contas_agencias = pd.merge(df_clientes_contas, df_agencias, on='cod_agencia', how='left')
df_completo = pd.merge(df_clientes_contas_agencias, df_transacoes, on='num_conta', how='left')

# %%
#dataframe completo
print("DataFrame Completo \n")
df_completo.info()

print("\n")
# Out:
# DataFrame Completo
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71999 entries, 0 to 71998
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   num_conta               71999 non-null  int64
#  1   cod_cliente             71999 non-null  int64
#  2   cod_agencia             71999 non-null  int64
#  3   cod_colaborador         71999 non-null  int64
#  4   tipo_conta              71999 non-null  object
#  5   data_abertura_x         71999 non-null  datetime64[ns, UTC]
#  6   saldo_total             71999 non-null  float64
#  7   saldo_disponivel        71999 non-null  float64
#  8   data_ultimo_lancamento  71999 non-null  datetime64[ns, UTC]
#  9   primeiro_nome           71921 non-null  object
#  10  ultimo_nome             71921 non-null  object
#  11  email                   71921 non-null  object
#  12  tipo_cliente            71921 non-null  object
# ...

# %%
df_completo.head()

print ("\n")

# %% [markdown]
# 5 - Desempenho das agências nos últimos 6 meses

# %%
#ultima transacao
data_mais_recente = df_completo['data_transacao'].max()
print(f"Transação mais recente foi em: {data_mais_recente}")

#data 6 meses antes
seis_meses_atras = data_mais_recente - pd.DateOffset(months=6)
print(f"Período de análise começou em: {seis_meses_atras}")

#transacoes durante esses meses
df_ultimos_6_meses = df_completo[df_completo['data_transacao'] >= seis_meses_atras]

print(f"\nTotal de transações no período completo: {len(df_completo)}")
print(f"Total de transações nos últimos 6 meses: {len(df_ultimos_6_meses)}")
# Out:
# Transação mais recente foi em: 2023-01-15 15:57:23.974201+00:00
# Período de análise começou em: 2022-07-15 15:57:23.974201+00:00
#
# Total de transações no período completo: 71999
# Total de transações nos últimos 6 meses: 31882

# %%
#value_counts pra contar transacoes por agencia
ranking_agencias = df_ultimos_6_meses['nome'].value_counts()

print(ranking_agencias)
# Out:
# nome
# Agência Digital           16806
# Agência Matriz             2345
# Agência Tatuapé            2246
# Agência Porto Alegre       2070
# Agência Rio de Janeiro     1968
# Agência Osasco             1723
# Agência Campinas           1705
# Agência Florianópolis      1524
# Agência Jardins            1121
# Agência Recife              374
# Name: count, dtype: int64

# %%
print("\n AS 3 MELHORES AGÊNCIAS:")
print(ranking_agencias.head(3))

print("\n AS 3 PIORES AGÊNCIAS:")
print(ranking_agencias.tail(3))

print("\n")
# Out:
#  AS 3 MELHORES AGÊNCIAS:
# nome
# Agência Digital    16806
# Agência Matriz      2345
# Agência Tatuapé     2246
# Name: count, dtype: int64
#
#  AS 3 PIORES AGÊNCIAS:
# nome
# Agência Florianópolis    1524
# Agência Jardins          1121
# Agência Recife            374
# Name: count, dtype: int64

# %% [markdown]
# 3 - Análise por dia da semana

# %%
df_completo['ano'] = df_completo['data_transacao'].dt.year
df_completo['mes'] = df_completo['data_transacao'].dt.month
df_completo['dia_da_semana_en'] = df_completo['data_transacao'].dt.day_name()

mapa_meses = {
    1: 'Janeiro', 2: 'Fevereiro', 3: 'Março', 4: 'Abril',
    5: 'Maio', 6: 'Junho', 7: 'Julho', 8: 'Agosto',
    9: 'Setembro', 10: 'Outubro', 11: 'Novembro', 12: 'Dezembro'
}

mapa_dias = {
    'Monday': 'Segunda-feira', 'Tuesday': 'Terça-feira', 'Wednesday': 'Quarta-feira',
    'Thursday': 'Quinta-feira', 'Friday': 'Sexta-feira', 'Saturday': 'Sábado',
    'Sunday': 'Domingo'
}

df_completo['nome_mes'] = df_completo['mes'].map(mapa_meses)
df_completo['dia_da_semana'] = df_completo['dia_da_semana_en'].map(mapa_dias)


df_completo[['data_transacao', 'ano', 'nome_mes', 'dia_da_semana']].head()
# Out:
#              data_transacao   ano  nome_mes  dia_da_semana
# 0 2014-11-18 23:44:31+00:00  2014  Novembro    Terça-feira
# 1 2014-12-22 09:49:47+00:00  2014  Dezembro  Segunda-feira
# 2 2015-01-05 04:03:15+00:00  2015   Janeiro  Segunda-feira
# 3 2015-04-18 16:12:31+00:00  2015     Abril         Sábado
# 4 2011-07-06 13:48:14+00:00  2011     Julho   Quarta-feira

# %%
dias_unicos = df_completo['dia_da_semana'].unique()

resultados = []

for dia_especifico in dias_unicos:

    transacoes_do_dia = df_completo[df_completo['dia_da_semana'] == dia_especifico]

    total_transacoes_dia = len(transacoes_do_dia)

    volume_total_dia = transacoes_do_dia['valor_transacao'].sum()

    resultados.append([dia_especifico, total_transacoes_dia, volume_total_dia])


analise_semana = pd.DataFrame(
    resultados,
    columns=['dia_da_semana', 'total_transacoes', 'volume_total_movimentado']
)


print("\nTabela Geral:")
print(analise_semana)
# Out:
# Tabela Geral:
#    dia_da_semana  total_transacoes  volume_total_movimentado
# 0    Terça-feira              7430                2232560.21
# 1  Segunda-feira              7176                3018450.16
# 2         Sábado              7380                2790520.53
# 3   Quarta-feira              7883                3589484.61
# 4    Sexta-feira             13571                3870517.83
# 5        Domingo              7439                3557910.12
# 6   Quinta-feira             21120                6646010.94

# %% [markdown]
# 3.1. Qual o dia da semana em que a média de transações aprovadas é maior e qual tem, também em média, maior volume movimentado?

# %%
transacoes_volume = analise_semana.sort_values(by='total_transacoes', ascending=False)
print("\n Número de Transações e volume total movimentado:")
print(transacoes_volume)

print("\n")
# Out:
#  Número de Transações e volume total movimentado:
#    dia_da_semana  total_transacoes  volume_total_movimentado
# 6   Quinta-feira             21120                6646010.94
# 4    Sexta-feira             13571                3870517.83
# 3   Quarta-feira              7883                3589484.61
# 5        Domingo              7439                3557910.12
# 0    Terça-feira              7430                2232560.21
# 2         Sábado              7380                2790520.53
# 1  Segunda-feira              7176                3018450.16

# %% [markdown]
# 3.2. Meses que são pares o volume médio de transações é significativamente maior do que os meses ímpares?

# %%
df_completo['paridade'] = df_completo['mes'].apply(lambda x: 'Par' if x % 2 == 0 else 'Ímpar')

#verificacao
print(df_completo[['nome_mes', 'paridade']].head())
# Out:
#    nome_mes paridade
# 0  Novembro    Ímpar
# 1  Dezembro      Par
# 2   Janeiro    Ímpar
# 3     Abril      Par
# 4     Julho    Ímpar

# %%
#transações em meses pares
transacoes_mes_par = df_completo[df_completo['paridade'] == 'Par']

#transações em meses impares
transacoes_mes_impar = df_completo[df_completo['paridade'] == 'Ímpar']


#media do valor da transacao de cada 
media_mes_par = transacoes_mes_par['valor_transacao'].mean()
media_mes_impar = transacoes_mes_impar['valor_transacao'].mean()


print("\n Valor Médio da Transação por Paridade: ")
print(f"O valor médio das transações em meses pares é:   R$ {media_mes_par:.2f}")
print(f"O valor médio das transações em meses impares é: R$ {media_mes_impar:.2f}")

print("\n")
# Out:
#  Valor Médio da Transação por Paridade:
# O valor médio das transações em meses pares é:   R$ 275.62
# O valor médio das transações em meses impares é: R$ 513.38

# %% [markdown]
# 4. Taxa de câmbio. Existe alguma relação do valor da moeda com o volume e o valor das transações (BCB)

# %%
from bcb import sgs
from datetime import datetime

# %%
data_inicio = df_completo['data_transacao'].min()
data_fim = df_completo['data_transacao'].max()

print(f"Período da análise: de {data_inicio.date()} a {data_fim.date()}")

lista_dfs_dolar = []

for ano in range(data_inicio.year, data_fim.year + 1, 8):
    start_chunk = datetime(ano, 1, 1)
    end_chunk = datetime(min(ano + 7, data_fim.year), 12, 31)


    df_chunk = sgs.get({'dolar': 1}, start=start_chunk, end=end_chunk)

    lista_dfs_dolar.append(df_chunk)

df_dolar_bcb = pd.concat(lista_dfs_dolar)

df_dolar_bcb = df_dolar_bcb.reset_index()
df_dolar_bcb = df_dolar_bcb.rename(columns={'Date': 'data', 'dolar': 'valor_dolar'})
# Out:
# Período da análise: de 2010-02-27 a 2023-01-15

# %%
print(df_dolar_bcb.head())
# Out:
#         data  valor_dolar
# 0 2010-01-04       1.7240
# 1 2010-01-05       1.7227
# 2 2010-01-06       1.7337
# 3 2010-01-07       1.7413
# 4 2010-01-08       1.7390

# %%
print(df_dolar_bcb.tail())
# Out:
#            data  valor_dolar
# 3509 2023-12-22       4.8619
# 3510 2023-12-26       4.8368
# 3511 2023-12-27       4.8306
# 3512 2023-12-28       4.8413
# 3513 2023-12-29       4.8413

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tabela_de_busca_dolar = df_dolar_bcb.set_index('data')['valor_dolar']


df_completo['data_para_busca'] = pd.to_datetime(df_completo['data_transacao'].dt.date)


df_completo['valor_dolar'] = df_completo['data_para_busca'].map(tabela_de_busca_dolar)


df_final = df_completo.dropna(subset=['valor_dolar']).copy()

correlacao = df_final['valor_dolar'].corr(df_final['valor_transacao'])
print(f"\ncoeficiente de correlação: {correlacao:.4f}")

print("Gráfico de dispersão")
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_final, x='valor_dolar', y='valor_transacao', alpha=0.1, color='gray')
plt.title('Relação entre Cotação do Dólar e Valor da Transação')
plt.xlabel('Valor do Dólar (R$)')
plt.ylabel('Valor da Transação (R$)')
plt.savefig('grafico_dolar.png', dpi=300)
plt.show()



print("\n")
# Out:
# coeficiente de correlação: -0.0299
# Gráfico de dispersão

# %% [markdown]
# Passando tabelas e gráfico de análise pro relatório latex

# %%
df_ranking = ranking_agencias.reset_index()
df_ranking.columns = ['Nome da Agência', 'Total de Transações']


print(df_ranking.head(3).to_latex(index=False))


print(df_ranking.tail(3).to_latex(index=False))
# Out:
# \begin{tabular}{lr}
# \toprule
# Nome da Agência & Total de Transações \\
# \midrule
# Agência Digital & 16806 \\
# Agência Matriz & 2345 \\
# Agência Tatuapé & 2246 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lr}
# \toprule
# Nome da Agência & Total de Transações \\
# \midrule
# Agência Florianópolis & 1524 \\
# Agência Jardins & 1121 \\
# Agência Recife & 374 \\
# \bottomrule
# \end{tabular}

# %%
data = {
    'Nome da Agência': ['Ag. Digital', 'Ag. Matriz', 'Ag. Tatuapé', 'Ag. Florianópolis', 'Ag. Jardins', 'Ag. Recife'],
    'Total de Transações': [16806, 2345, 2246, 1524, 1121, 374]
}
df_agencias = pd.DataFrame(data).sort_values('Total de Transações', ascending=False)

plt.style.use('seaborn-v0_8-whitegrid') 
fig, ax = plt.subplots(figsize=(12, 7))

bars = ax.bar(df_agencias['Nome da Agência'], df_agencias['Total de Transações'], color='gray')

for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2.0, yval + 100, int(yval), ha='center', va='bottom')

ax.set_title('Volume de Transações por Agência (Últimos 6 Meses)', fontsize=16)
ax.set_ylabel('Total de Transações', fontsize=12)
ax.set_xlabel('Agências', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout() 

plt.savefig('grafico_agencias.pdf', format='pdf')
plt.show()

# %%
import matplotlib.ticker as mtick

# %%
data = {
    'dia_da_semana': ['Quinta-feira', 'Sexta-feira', 'Quarta-feira', 'Domingo', 'Terça-feira', 'Sábado', 'Segunda-feira'],
    'volume_total_movimentado': [6646010.94, 3870517.83, 3589484.61, 3557910.12, 2232560.21, 2790520.53, 3018450.16]
}
df_dias = pd.DataFrame(data)

dias_ordem = ['Segunda-feira', 'Terça-feira', 'Quarta-feira', 'Quinta-feira', 'Sexta-feira', 'Sábado', 'Domingo']
df_dias['dia_da_semana'] = pd.Categorical(df_dias['dia_da_semana'], categories=dias_ordem, ordered=True)
df_dias = df_dias.sort_values('dia_da_semana')

plt.style.use('seaborn-v0_8-whitegrid')
fig, ax = plt.subplots(figsize=(12, 7))

bars = ax.bar(df_dias['dia_da_semana'], df_dias['volume_total_movimentado'], color='grey')

ax.set_title('Volume Total Movimentado por Dia da Semana', fontsize=16)
ax.set_ylabel('Volume Movimentado (em Milhões de R$)', fontsize=12)
plt.xticks(rotation=45, ha='right')

def format_millions(x, pos):
    return f'R$ {x/1_000_000:.1f}M'
ax.yaxis.set_major_formatter(mtick.FuncFormatter(format_millions))

plt.tight_layout()

plt.savefig('grafico_volume_semanal.pdf', format='pdf')
plt.show()

# %%
df_completo.to_csv('dados_banvic_para_dashboard.csv', index=False)
